# %% [markdown]
# ## Computer Vision Driving Car

# %% [markdown]
# ### installing libs

# %%
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (8.4.11)
# Requirement already satisfied: opencv-python in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (4.13.0.90)
# Requirement already satisfied: pandas in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: torch in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (2.10.0)
# Requirement already satisfied: scikit-learn in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: scipy in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (1.17.0)
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.23.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: pillow>=7.1.2 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from ultralytics) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: torchvision>=0.9.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from ultralytics) (7.2.1)
# Requirement already satisfied: polars>=0.20.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from ultralytics) (1.38.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: filelock in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch) (1.3.3)
# Requirement already satisfied: joblib>=1.3.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: polars-runtime-32==1.38.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from polars>=0.20.0->ultralytics) (1.38.0)
# Requirement already satisfied: six>=1.5 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kakashi/Documents/Projects/AI/Tutorials/Data Science/.venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (pyproject.toml) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110543 sha256=dfcb40504bac0f03c1b9d70dfdf53e7b7f70db1e000fcfc725ac305cc536d320
#   Stored in directory: /home/kakashi/.cache/pip/wheels/77/bf/4c/b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built filterpy
# Installing collected packages: filterpy
# Successfully installed filterpy-1.4.5
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Config

# %%
ALLOWED_CLASSES = {
    0: "Pedestrian",
    2: "Car",
    3: "Motorcycle",
    5: "Bus",
    7: "Truck"
}
CLASS_COLORS = {
    0: (255, 255, 0),    # Pedestrian - Cyan
    2: (0, 255, 0),      # Car - Green
    3: (255, 0, 255),    # Motorcycle - Magenta
    5: (0, 0, 255),      # Bus - Red
    7: (255, 165, 0)     # Truck - Orange
}
MODEL_NAME = "yolov8n.pt"
VIDEO_PATH = "challenge-mle2.mp4"
OUTPUT_VIDEO = "output_tracking.mp4"
OUTPUT_CSV = "tracking_results.csv"

# %% [markdown]
# ## IMPORTS

# %%
import cv2
import time
from ultralytics import YOLO
import numpy as np
from pathlib import Path

# %% [markdown]
# ## YOLOv8 + ByteTrack Detection & Tracking Pipeline

# %%
import cv2
import time
import csv
from ultralytics import YOLO


def tracking_1(
    video_path: str,
    output_video_path: str,
    output_csv_path: str,
    model_name: str = "yolov8n.pt",
    conf: float = 0.4,
    iou: float = 0.5
):
    model = YOLO(model_name)

    cap = cv2.VideoCapture(video_path)
    assert cap.isOpened(), "Cannot open input video or cant find the video"

    # Lock frame size using first frame (CRITICAL)
    ret, frame = cap.read()
    assert ret, "Failed to read video frames"

    height, width = frame.shape[:2]

    # Safe FPS
    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps <= 1 or fps > 120:
        fps = 30

    # MP4 writer
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))
    assert out.isOpened(), "error in saving video"

    csv_file = open(output_csv_path, mode="w", newline="")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(
        ["frame_id", "object_id", "class", "x1", "y1", "x2", "y2"]
    )

    prev_time = time.time()
    frame_id = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.resize(frame, (width, height))

        results = model.track(
            frame,
            persist=True,
            tracker="bytetrack.yaml",
            conf=conf,
            iou=iou,
            verbose=False
        )

        if results[0].boxes.id is not None:
            boxes = results[0].boxes.xyxy.cpu().numpy()
            ids = results[0].boxes.id.cpu().numpy()
            classes = results[0].boxes.cls.cpu().numpy()

            for box, track_id, cls_id in zip(boxes, ids, classes):
                cls_id = int(cls_id)
                if cls_id not in ALLOWED_CLASSES:
                    continue

                x1, y1, x2, y2 = map(int, box)
                object_id = int(track_id)
                class_name = ALLOWED_CLASSES[cls_id]

                # write csv row
                csv_writer.writerow([
                    frame_id,
                    object_id,
                    class_name,
                    x1, y1, x2, y2
                ])

                color = CLASS_COLORS[cls_id]
                label = f"{class_name} | ID {object_id}"

                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                cv2.putText(
                    frame,
                    label,
                    (x1, y1 - 8),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.6,
                    color,
                    2
                )

        # FPS overlay
        now = time.time()
        fps_text = f"FPS: {1 / (now - prev_time + 1e-6):.1f}"
        prev_time = now

        cv2.putText(
            frame,
            fps_text,
            (20, 40),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255),
            2
        )

        out.write(frame)
        cv2.imshow("YOLOv8 + ByteTrack", frame)

        frame_id += 1

        if cv2.waitKey(1) & 0xFF == 27:
            break

    cap.release()
    out.release()
    csv_file.close()
    cv2.destroyAllWindows()

    print(f"Video saved to: {output_video_path}")
    print(f"CSV saved to: {output_csv_path}")

# %%
tracking_1(
    video_path=VIDEO_PATH,
    output_video_path=OUTPUT_VIDEO,
    output_csv_path=OUTPUT_CSV,
    model_name=MODEL_NAME
)
# Out:
# Video saved to: output_tracking.mp4
# CSV saved to: tracking_results.csv

# %%
from IPython.display import Video

Video('output_tracking.mp4', width=640, height=360)
# Out:
# <video src="output_tracking.mp4" controls  width="640"  height="360">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
import cv2
import time
import csv
from ultralytics import YOLO


def tracking_2(
    video_path: str,
    output_video_path: str,
    output_csv_path: str,
    model_name: str = "yolov8n.pt",
    conf: float = 0.4,
    iou: float = 0.5
):

    model = YOLO(model_name)

    cap = cv2.VideoCapture(video_path)
    assert cap.isOpened(), "Cannot open input video or cant find the video"

    # Lock frame size
    ret, frame = cap.read()
    assert ret, "Failed to read frames"
    height, width = frame.shape[:2]

    # Safe FPS
    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps <= 1 or fps > 120:
        fps = 30

    # MP4 writer
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))
    assert out.isOpened(), "can not save the video"

    # CSV setup
    csv_file = open(output_csv_path, mode="w", newline="")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["frame_id", "object_id", "class", "x1", "y1", "x2", "y2"])

    prev_time = time.time()
    frame_id = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.resize(frame, (width, height))

        results = model.track(
            frame,
            persist=True,
            tracker="botsort.yaml",   # BoT-SORT with ReID
            conf=conf,
            iou=iou,
            verbose=False
        )

        if results[0].boxes.id is not None:
            boxes = results[0].boxes.xyxy.cpu().numpy()
            ids = results[0].boxes.id.cpu().numpy()
            classes = results[0].boxes.cls.cpu().numpy()

            for box, track_id, cls_id in zip(boxes, ids, classes):
                cls_id = int(cls_id)
                if cls_id not in ALLOWED_CLASSES:
                    continue

                x1, y1, x2, y2 = map(int, box)
                object_id = int(track_id)
                class_name = ALLOWED_CLASSES[cls_id]

                # Write CSV row
                csv_writer.writerow([
                    frame_id,
                    object_id,
                    class_name,
                    x1, y1, x2, y2
                ])

                # Draw
                color = CLASS_COLORS[cls_id]
                label = f"{class_name} | ID {object_id}"

                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                cv2.putText(
                    frame,
                    label,
                    (x1, y1 - 8),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.6,
                    color,
                    2
                )

        # FPS overlay
        now = time.time()
        fps_text = f"FPS: {1 / (now - prev_time + 1e-6):.1f}"
        prev_time = now

        cv2.putText(
            frame,
            fps_text,
            (20, 40),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255),
            2
        )

        out.write(frame)
        cv2.imshow("YOLOv8 + BOT-SORT optimized algorithm", frame)

        frame_id += 1

        if cv2.waitKey(1) & 0xFF == 27:
            break

    cap.release()
    out.release()
    csv_file.close()
    cv2.destroyAllWindows()

    print(f"Video saved to: {output_video_path}")
    print(f"CSV saved to: {output_csv_path}")

# %%
tracking_2(
    video_path=VIDEO_PATH,
    output_video_path=OUTPUT_VIDEO,
    output_csv_path=OUTPUT_CSV,
    model_name=MODEL_NAME
)
# Out:
# Video saved to: output_tracking.mp4
# CSV saved to: tracking_results.csv
